# %%
import pandas as pd
import numpy as np

csv_file_path = 'PY_STRESS.csv'

df = pd.read_csv(csv_file_path, index_col='No')

df.info('Journal')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174 entries, 1 to 174
# Data columns (total 28 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                     174 non-null    int64
#  1   Publication                                                                                                    171 non-null    object
#  2   Authors                                                                                                        171 non-null    object
#  3   Year                                                                                                           169 non-null    float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0                                        Publication  \
# No
# 1             1  How simulation modelling can help reduce the i...
# 2             2  The ODD protocol for describing agent-based an...
# 3             3     Operational Research: methods and applications
# 4             4  Extensions of fuzzy cognitive maps: a systemat...
# 5             5  Estimation of Viral Aerosol Emissions From Sim...
# ..          ...                                                ...
# 170         170  Enabling same-day delivery using a drone resup...
# 171         171  A discrete-event simulation study for pre-hosp...
# 172         172                                                NaN
# 173         173                                                NaN
# 174         174                                                NaN
#
#                                                Authors    Year Type of paper  \
# No
# ...

# %%
df.info("Year")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174 entries, 1 to 174
# Data columns (total 28 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                     174 non-null    int64
#  1   Publication                                                                                                    171 non-null    object
#  2   Authors                                                                                                        171 non-null    object
#  3   Year                                                                                                           169 non-null    float64
# ...

# %%
df.filter
# Out:
# <bound method NDFrame.filter of      Unnamed: 0                                        Publication  \
# No
# 1             1  How simulation modelling can help reduce the i...
# 2             2  The ODD protocol for describing agent-based an...
# 3             3     Operational Research: methods and applications
# 4             4  Extensions of fuzzy cognitive maps: a systemat...
# 5             5  Estimation of Viral Aerosol Emissions From Sim...
# ..          ...                                                ...
# 170         170  Enabling same-day delivery using a drone resup...
# 171         171  A discrete-event simulation study for pre-hosp...
# 172         172                                                NaN
# 173         173                                                NaN
# 174         174                                                NaN
#
#                                                Authors    Year Type of paper  \
# No
# ...

# %%
df.filter(like='Journal')
# Out:
#                                                Journal
# No
# 1                                Journal of Simulation
# 2    Journal of Artificial Societies and Social Sim...
# 3          Journal of the Operational Research Society
# 4                                ACM Computing Surveys
# 5                                                 JAMA
# ..                                                 ...
# 170                   Computational Management Science
# 171                              Journal of Simulation
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
# [174 rows x 1 columns]

# %%
df.filter(like='Journal').describe()
# Out:
#                              Journal
# count                            163
# unique                            90
# top     Winter Simulation Conference
# freq                              21

# %%
USED_STRESS = df.describe().T.loc['Used?']['Yes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Used?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 USED_STRESS = df.describe().T.loc['Used?']['Yes']
#
# ...

# %%
USED_STRESS = df.describe().loc['Used?']['Yes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Used?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 USED_STRESS = df.describe().loc['Used?']['Yes']
#
# ...

# %%
USED_STRESS = df.loc['Used?']['Yes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Used?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 USED_STRESS = df.loc['Used?']['Yes']
#
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %%
USED_STRESS = df.describe().loc['Used?']['Yes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Used?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 USED_STRESS = df.describe().loc['Used?']['Yes']
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                        Publication  \
# No
# 1             1  How simulation modelling can help reduce the i...
# 2             2  The ODD protocol for describing agent-based an...
# 3             3     Operational Research: methods and applications
# 4             4  Extensions of fuzzy cognitive maps: a systemat...
# 5             5  Estimation of Viral Aerosol Emissions From Sim...
# ..          ...                                                ...
# 170         170  Enabling same-day delivery using a drone resup...
# 171         171  A discrete-event simulation study for pre-hosp...
# 172         172                                                NaN
# 173         173                                                NaN
# 174         174                                                NaN
#
#                                                Authors    Year Type of paper  \
# No
# ...

# %%
df.shape
# Out:
# (174, 28)

# %%
USED_STRESS = df[df['Used?'] == 'Yes']

# %%
USED_STRESS.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                        Publication  \
# No
# 5             5  Estimation of Viral Aerosol Emissions From Sim...
# 8             8  Developing sustainable tourism destinations th...
# 10           10  Beyond ratios - flexible and resilient nurse s...
# 12           12  Designing optimal COVID-19 testing stations lo...
# 13           13  A predictive model for the post-pandemic delay...
# ..          ...                                                ...
# 161         161                                     Not in English
# 162         162   Effective Provision of Critical Care\r\nServices
# 163         163  Online Simulation for the Operational Manageme...
# 170         170  Enabling same-day delivery using a drone resup...
# 171         171  A discrete-event simulation study for pre-hosp...
#
#                                                Authors    Year Type of paper  \
# No
# ...

# %%
USED_STRESS.info('Journal')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 5 to 171
# Data columns (total 28 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                     74 non-null     int64
#  1   Publication                                                                                                    74 non-null     object
#  2   Authors                                                                                                        74 non-null     object
#  3   Year                                                                                                           74 non-null     float64
# ...

# %%
USED_STRESS.describe('Journal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 USED_STRESS.describe('Journal')
#
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
USED_STRESS.shape
# Out:
# (74, 28)

# %%
USED_STRESS.info('Software')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 5 to 171
# Data columns (total 28 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                     74 non-null     int64
#  1   Publication                                                                                                    74 non-null     object
#  2   Authors                                                                                                        74 non-null     object
#  3   Year                                                                                                           74 non-null     float64
# ...

# %%
USED_STRESS.describe('Software')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 USED_STRESS.describe('Software')
#
# File c:\Anaconda\envs\stress\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
print(USED_STRESS.describe())
# Out:
#        Unnamed: 0         Year  ...27
# count   74.000000    74.000000    0.0
# mean    80.648649  2021.716216    NaN
# std     47.013677     1.360099    NaN
# min      5.000000  2018.000000    NaN
# 25%     38.500000  2021.000000    NaN
# 50%     77.000000  2022.000000    NaN
# 75%    118.000000  2023.000000    NaN
# max    171.000000  2024.000000    NaN

# %%
print(USED_STRESS.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 5 to 171
# Data columns (total 28 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                     74 non-null     int64
#  1   Publication                                                                                                    74 non-null     object
#  2   Authors                                                                                                        74 non-null     object
#  3   Year                                                                                                           74 non-null     float64
# ...
